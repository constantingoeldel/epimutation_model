# %% [markdown]
# # Build Pedigree Graph from Nodelist and Edgelist

# %%
import networkx as nx

G = nx.DiGraph()

with open("nodelist.txt") as f:
    nodes = f.read().splitlines()

with open("edgelist.txt") as f:
    edges = f.read().splitlines()

for node in nodes: 

    if node == "filename,node,gen,meth" or node == "":
        continue
    
    filename, node, gen, meth = node.split(',')
    
    node = {
        'filename': filename,
        'node': node,
        'gen': int(gen),
        'meth': True if meth == 'Y' else False
    }

    

    G.add_node(node['node'], **node)

for edge in edges:

    if edge == "from,to":
        continue

    from_, to_ = edge.split(',')

    G.add_edge(from_, to_)

def get_predecessor_node(node):
    if not node in G:
        return None

    pred = iter(G.pred[node])

    if pred.__length_hint__() == 0:
        return None

    pred = G.nodes[next(pred)]

    if pred["meth"]:
        return pred
    else:
        return get_predecessor_node(pred['node'])

def get_pred_node_by_gen_and_line(gen, line):
    pred =  get_predecessor_node(f"{gen}_{line}")
    if pred is None:
        return None, None
    gen, line = pred["node"].split('_')
    return int(gen), int(line)

# %% [markdown]
# # Hyperparamters

# %%
import torch

batch_size = 32

cs_neighbours = 5
hist_mod_neighbours = 20
gene_neighbours = 1
meth_neighbours = 20

mutables = 5 # not implemented yet

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
import torch
import clickhouse_connect
import polars as pl
import time

class Sites(torch.utils.data.IterableDataset):
    def __init__(self, mode="train"):
        super(Sites).__init__()
        self.mode = mode

        self.client = clickhouse_connect.get_client(host='localhost', username='cgoeldel', password='Goe1409ldel')
        genes = self.client.query_arrow(f"select * from genes where chromosome < 5") if mode == "train" else self.client.query_arrow(f"select * from genes where chromosome = 5")
        self.genes = pl.DataFrame(genes)




        # self.samples_per_chrom = pl.DataFrame(self.client.query_arrow("select chromosome, count(*) from methylome_within_gbM where generation = 0 group by chromosome").result_rows[0][0])
        # self.samples = self.client.query("select count(distinct(generation, line)) from methylome_within_gbM").results_rows[0][0]
        # self.hist_mod_dict = {  
        #         "input" : 1,
        #         "H3" : 2,
        #         "H3K4Me1" : 3,
        #         "H3K27Me3" : 4,
        #         "H2AZ" : 5,
        #         "H3K56Ac" : 6,
        #         "H3K4Me3" : 7    
        #         }

    
    def __iter__(self):
        for gene in self.genes.iter_rows(named=True):
            tic = time.perf_counter()

            # TODO: more elegant way to iterate over all pedigree branches
            gene_length = gene['end'] - gene['start']
            sites_line_2 = self.client.query_arrow(f"select location - {gene['start']} as start_diff, {gene['end']} -location as end_diff, location * 1.0 / ({gene_length}) as percentile, meth_lvl from methylome_within_gbM where chromosome = {gene['chromosome']} and (line = 2 or line = 0)  and strand = {gene['strand']} and location between {gene['start']} and {gene['end']} order by generation, line, start_diff")
            sites_line_2 = pl.DataFrame(sites_line_2)
            # sites_line_8 = self.client.query_arrow(f"select location - {gene['start']} as start_diff, {gene['end']} -location as end_diff, location * 1.0 / ({gene_length}) as percentile, meth_lvl from methylome_within_gbM where chromosome = {gene['chromosome']} and (line = 8 or line = 0)  and strand = {gene['strand']} and location between {gene['start']} and {gene['end']} order by generation, line, start_diff")
            # sites_line_8 = pl.DataFrame(sites_line_8)
            print(sites_line_2.shape)
            display(gene)
       
            targets_line_2 = sites_line_2['meth_lvl'].to_numpy()
            # targets_line_8 = sites_line_8['meth_lvl'].to_numpy()

            targets_line_2 = torch.tensor(targets_line_2, dtype=torch.float32)
            # targets_line_8 = torch.tensor(targets_line_8, dtype=torch.float32)

            targets_line_2 = targets_line_2.reshape(gene_length, 6)
            # targets_line_8 = targets_line_8.reshape(gene_length, 6)

            targets_line_2 = targets_line_2[1:, :] # remove first row, these can not be predicted as there is no predecessor
            # targets_line_8 = targets_line_8[1:, :]
            
            sites_line_2 = torch.tensor(sites_line_2.to_numpy(), dtype=torch.float32).reshape(gene_length * 4, 6)
            # sites_line_8 = torch.tensor(sites_line_8.to_numpy(), dtype=torch.float32).reshape(gene_length, 6)

            # remove the last row, these have no predecessor, so no known target
            sites_line_2 = sites_line_2[:-1, :]
            # sites_line_8 = sites_line_8[:-1, :]

            chr_states = self.client.query_arrow(f"select state, ({gene['start']} - start ) as start_diff, ({gene['end']} - end) as end_diff from chr_states where chromosome = {gene['chromosome']} and start between {gene['start']} and {gene['end']} and end between {gene['start']} and {gene['end']}")
            chr_states = pl.DataFrame(chr_states)

            chr_states_and_gene = chr_states.vstack(gene)

            chr_states = torch.tensor(chr_states_and_gene.to_numpy(), dtype=torch.float32)

            print(sites_line_2.shape)
            # print(sites_line_8.shape)
            print(chr_states.shape)
            print(targets_line_2.shape)
            # print(targets_line_8.shape)

            # every last node -> list back to root: decoder 
            # surrounding methylome -> encoder
            # surrounding gene + chromatine state -> encoder
            x = sites_line_2.to(device)
            c = chr_states.to(device)
            t = targets_line_2.to(device)


            toc = time.perf_counter()
            print(f"Gene {gene['chromosome']}:{gene['start']}:{gene['end']} in {toc - tic:0.4f} seconds")
            yield x, c, t

# %%
def save_surroundings(chromosome, location, idx, targets, mode="train"): 
    idx = idx.tolist()
    targets = targets.tolist()
    data = [chromosome, location, idx, targets, mode]
    
    client.insert("training_data", [data], column_names=["chromosome", "location", "prompt", "targets", "mode"])

# %%
def get_neighbours(site, mode="train"):
    # get surrounding genes
    tic = time.perf_counter()
    genes = client.query_arrow(f"select type, ({site['location']} - start) as start_diff, ({site['location']} - end) as end_diff from genes where chromosome = {site['chromosome']} and strand = {site['strand']} order by abs(start_diff) limit {gene_neighbours}")
    g = pl.DataFrame(genes)

    toc = time.perf_counter()
    # print(f"genes in {toc - tic:0.4f} seconds")
    # display(g)
    # Get surrounding histone mods 
    tic = time.perf_counter()

    offset = 200
    sufficient = False
    while not sufficient:
        histone_mods = client.query_arrow(f"select modification, ({site['location']} - start ) as start_diff, ({site['location']} - end) as end_diff from histone_mods where chromosome = {site['chromosome']} and start > {site['location'] - offset} and end < {site['location'] + offset} order by abs(start_diff) limit {hist_mod_neighbours}")
        h = pl.DataFrame(histone_mods)
        if len(h) == hist_mod_neighbours:
            sufficient = True
        else:
            print(f"Only {len(h)} histone mods found, increasing offset to {offset * 2}")
            offset *= 2
            continue

        h = h.with_columns(pl.col("modification").map_dict(hist_mod_dict).alias("modification"))
    
    toc = time.perf_counter()
    # print(f"Histone mods in {toc - tic:0.4f} seconds")
    # display(h)
    # Get surrounding chromatine states
    tic = time.perf_counter()
    chr_states = client.query_arrow(f"select state, ({site['location']} - start ) as start_diff, ({site['location']} -end) as end_diff from chr_states where chromosome = {site['chromosome']} order by abs(start_diff) limit {cs_neighbours } ")
    c = pl.DataFrame(chr_states)

    toc = time.perf_counter()
    # print(f"Chromatine State in {toc - tic:0.4f} seconds")
    # display(c)
    # Get each site in all generations and lines 
    tic = time.perf_counter()
    offset = 200
    sufficient = False
    while not sufficient:
        all_generations_and_neighbours = client.query_arrow(f"select * except (trinucleotide_context, pedigree, id), ({site['location']} - location ) as location_diff from methylome where chromosome = {site['chromosome']} and strand = {site['strand']} and location between  {site['location'] - offset} and  {site['location'] + offset} order by abs(location_diff), location_diff, generation, line limit {(meth_neighbours +1)  * samples}")
        m = pl.DataFrame(all_generations_and_neighbours) # (meth_neighbours * samples, 12)
        if len(m) == (meth_neighbours +1)  * samples:
            sufficient = True
        else:
            print(f"Only {len(m)} neighbours found, increasing offset to {offset * 2}")
            offset *= 2
            continue
    # display(m)

    toc = time.perf_counter()
    # print(f"neighbours in {toc - tic:0.4f} seconds")                
    tic = time.perf_counter()
    site_across_generations = m.filter(pl.col("location_diff") == 0)
    m = m.filter(pl.col("location_diff") != 0)
   
    m = m.filter((pl.col("generation") != 0) & (pl.col("line") != 0))

    preds = []
    targets = []
    for site in site_across_generations.iter_rows(named=True):
        pred_gen, pred_line = get_pred_node_by_gen_and_line(site["generation"], site["line"])
        if not pred_gen is None:
            pred = site_across_generations.filter((pl.col("generation") == pred_gen) & (pl.col("line") == pred_line)) # (1, 12)
            preds.append(torch.tensor(pred.to_numpy()[0], dtype=torch.float32))
            targets.append(site["meth_lvl"])

    toc = time.perf_counter()
    # print(f"Filtering for {toc - tic:0.4f} seconds")    
    tic = time.perf_counter()
    t = torch.tensor(targets, dtype=torch.float32)
    p = torch.stack(preds) # (samples - 1, 12)
    g = torch.tensor(g.to_numpy(), dtype=torch.float32) 
    m = torch.tensor(m.to_numpy(),dtype=torch.float32).T 
    h = torch.tensor(h.to_numpy(),dtype=torch.float32)
    c = torch.tensor(c.to_numpy(),dtype=torch.float32)

    m = m.reshape((samples-1), 12 * meth_neighbours) # (samples -1, concatenated neighbours)
    
    # These are time-invariant
    g = g.reshape(3 * gene_neighbours)
    h = h.reshape(3 * hist_mod_neighbours)
    c = c.reshape(3* cs_neighbours)

    # surroundings 
    s = torch.cat([g, c, h])
    s = s.expand((samples -1), -1)

    x = torch.cat([m, p, s], dim=1)

    toc = time.perf_counter()
    # print(f"Reshaping in {toc - tic:0.4f} seconds")
    save_surroundings(site["chromosome"], site["location"], x, t, mode)

    return x, t

# %%
import time
import numpy as np



def create_all_samples():

    start = 0
    end = 1e6
    total = 557173708

    while start < total:
        next_samples = client.query_arrow(f"select * except (trinucleotide_context, pedigree, id) from methylome where generation = 0 and context = 'CG' and location between {start} and {end} order by chromosome, location, strand")
        df = pl.DataFrame(next_samples)

        print(f"Creating {df.height} samples in range {start} to {end}")
        i = 0
        for site in df.iter_rows(named=True):
            tic = time.perf_counter()
            mode = np.random.choice(["train", "test", "validation"], p=[0.8, 0.1, 0.1])
            print(f"Creating sample {i} in mode {mode} at location {site['location']} on chromosome {site['chromosome']}")
            get_neighbours(site, mode)
            toc = time.perf_counter()
            print(f"Created sample {i} in {toc - tic:0.4f} seconds")
            i += 1
        
        start = end
        end = end + 1e6


tic = time.perf_counter()
# create_all_samples()
toc = time.perf_counter()
print(f"Creating all samples in {toc - tic:0.4f} seconds")
# Out:
# Creating 254372 samples in range 0 to 1000000.0
# Creating sample 0 in mode test at location 109 on chromosome 1
# Created sample 0 in 0.0418 seconds
# Creating sample 1 in mode train at location 110 on chromosome 1
# Created sample 1 in 0.0423 seconds
# Creating sample 2 in mode train at location 115 on chromosome 1
# Created sample 2 in 0.0364 seconds
# Creating sample 3 in mode train at location 116 on chromosome 1
# Created sample 3 in 0.0385 seconds
# Creating sample 4 in mode train at location 161 on chromosome 1
# Created sample 4 in 0.0372 seconds
# Creating sample 5 in mode train at location 162 on chromosome 1
# Created sample 5 in 0.0389 seconds
# Creating sample 6 in mode train at location 310 on chromosome 1
# Created sample 6 in 0.0380 seconds
# Creating sample 7 in mode train at location 311 on chromosome 1
# Created sample 7 in 0.0389 seconds
# Creating sample 8 in mode train at location 500 on chromosome 1
# Created sample 8 in 0.0375 seconds
# Creating sample 9 in mode train at location 501 on chromosome 1
# Created sample 9 in 0.0384 seconds
# Creating sample 10 in mode train at location 511 on chromosome 1
# Created sample 10 in 0.0356 seconds
# Creating sample 11 in mode train at location 512 on chromosome 1
# Created sample 11 in 0.0405 seconds
# Creating sample 12 in mode train at location 642 on chromosome 1
# Created sample 12 in 0.0366 seconds
# Creating sample 13 in mode train at location 643 on chromosome 1
# Created sample 13 in 0.0379 seconds
# Creating sample 14 in mode train at location 647 on chromosome 1
# Created sample 14 in 0.0351 seconds
# Creating sample 15 in mode train at location 648 on chromosome 1
# Created sample 15 in 0.0379 seconds
# Creating sample 16 in mode validation at location 650 on chromosome 1
# Created sample 16 in 0.0364 seconds
# Creating sample 17 in mode test at location 651 on chromosome 1
# Created sample 17 in 0.0392 seconds
# Creating sample 18 in mode train at location 790 on chromosome 1
# Created sample 18 in 0.0355 seconds
# Creating sample 19 in mode train at location 791 on chromosome 1
# Created sample 19 in 0.0391 seconds
# Creating sample 20 in mode train at location 809 on chromosome 1
# Created sample 20 in 0.0362 seconds
# Creating sample 21 in mode train at location 810 on chromosome 1
# Created sample 21 in 0.0379 seconds
# Creating sample 22 in mode train at location 839 on chromosome 1
# Created sample 22 in 0.0368 seconds
# Creating sample 23 in mode train at location 840 on chromosome 1
# Created sample 23 in 0.0385 seconds
# Creating sample 24 in mode train at location 904 on chromosome 1
# Created sample 24 in 0.0384 seconds
# Creating sample 25 in mode validation at location 905 on chromosome 1
# Created sample 25 in 0.0383 seconds
# Creating sample 26 in mode train at location 911 on chromosome 1
# Created sample 26 in 0.0366 seconds
# Creating sample 27 in mode train at location 912 on chromosome 1
# Created sample 27 in 0.0395 seconds
# Creating sample 28 in mode train at location 948 on chromosome 1
# Created sample 28 in 0.0364 seconds
# Creating sample 29 in mode train at location 949 on chromosome 1
# Created sample 29 in 0.0448 seconds
# Creating sample 30 in mode train at location 1324 on chromosome 1
# Created sample 30 in 0.0374 seconds
# Creating sample 31 in mode train at location 1325 on chromosome 1
# Created sample 31 in 0.0430 seconds
# Creating sample 32 in mode test at location 1439 on chromosome 1
# Created sample 32 in 0.0421 seconds
# Creating sample 33 in mode test at location 1440 on chromosome 1
# Created sample 33 in 0.0522 seconds
# Creating sample 34 in mode train at location 1541 on chromosome 1
# Created sample 34 in 0.0477 seconds
# Creating sample 35 in mode train at location 1542 on chromosome 1
# Created sample 35 in 0.0385 seconds
# Creating sample 36 in mode train at location 1634 on chromosome 1
# Created sample 36 in 0.0405 seconds
# Creating sample 37 in mode train at location 1635 on chromosome 1
# Created sample 37 in 0.0377 seconds
# Creating sample 38 in mode train at location 1649 on chromosome 1
# Created sample 38 in 0.0371 seconds
# Creating sample 39 in mode train at location 1650 on chromosome 1
# Created sample 39 in 0.0383 seconds
# Creating sample 40 in mode train at location 1778 on chromosome 1
# Created sample 40 in 0.0461 seconds
# Creating sample 41 in mode train at location 1779 on chromosome 1
# Created sample 41 in 0.0412 seconds
# Creating sample 42 in mode train at location 1943 on chromosome 1
# Created sample 42 in 0.0406 seconds
# Creating sample 43 in mode train at location 1944 on chromosome 1
# Created sample 43 in 0.0395 seconds
# Creating sample 44 in mode train at location 2024 on chromosome 1
# Created sample 44 in 0.0382 seconds
# Creating sample 45 in mode train at location 2025 on chromosome 1
# Created sample 45 in 0.0390 seconds
# Creating sample 46 in mode train at location 2194 on chromosome 1
# Created sample 46 in 0.0479 seconds
# Creating sample 47 in mode test at location 2195 on chromosome 1
# Created sample 47 in 0.0432 seconds
# Creating sample 48 in mode validation at location 2257 on chromosome 1
# Created sample 48 in 0.0380 seconds
# Creating sample 49 in mode train at location 2258 on chromosome 1
# Created sample 49 in 0.0400 seconds
# Creating sample 50 in mode test at location 2296 on chromosome 1
# Created sample 50 in 0.0372 seconds
# Creating sample 51 in mode train at location 2297 on chromosome 1
# Created sample 51 in 0.0392 seconds
# Creating sample 52 in mode train at location 2400 on chromosome 1
# Created sample 52 in 0.0386 seconds
# Creating sample 53 in mode validation at location 2401 on chromosome 1
# Created sample 53 in 0.0390 seconds
# Creating sample 54 in mode train at location 2431 on chromosome 1
# Created sample 54 in 0.0374 seconds
# Creating sample 55 in mode train at location 2432 on chromosome 1
# Created sample 55 in 0.0401 seconds
# Creating sample 56 in mode train at location 2437 on chromosome 1
# Created sample 56 in 0.0387 seconds
# Creating sample 57 in mode test at location 2438 on chromosome 1
# Created sample 57 in 0.0390 seconds
# Creating sample 58 in mode validation at location 2478 on chromosome 1
# Created sample 58 in 0.0376 seconds
# Creating sample 59 in mode train at location 2479 on chromosome 1
# Created sample 59 in 0.0387 seconds
# Creating sample 60 in mode train at location 2509 on chromosome 1
# Created sample 60 in 0.0370 seconds
# Creating sample 61 in mode train at location 2510 on chromosome 1
# Created sample 61 in 0.0387 seconds
# Creating sample 62 in mode train at location 2688 on chromosome 1
# Created sample 62 in 0.0381 seconds
# Creating sample 63 in mode train at location 2689 on chromosome 1
# Created sample 63 in 0.0383 seconds
# Creating sample 64 in mode train at location 2807 on chromosome 1
# Created sample 64 in 0.0421 seconds
# Creating sample 65 in mode validation at location 2808 on chromosome 1
# Created sample 65 in 0.0405 seconds
# Creating sample 66 in mode train at location 2830 on chromosome 1
# Created sample 66 in 0.0450 seconds
# Creating sample 67 in mode train at location 2831 on chromosome 1
# Created sample 67 in 0.0436 seconds
# Creating sample 68 in mode train at location 2845 on chromosome 1
# Created sample 68 in 0.0414 seconds
# Creating sample 69 in mode train at location 2846 on chromosome 1
# Created sample 69 in 0.0465 seconds
# Creating sample 70 in mode train at location 2857 on chromosome 1
# Created sample 70 in 0.0410 seconds
# Creating sample 71 in mode train at location 2858 on chromosome 1
# Created sample 71 in 0.0432 seconds
# Creating sample 72 in mode train at location 2866 on chromosome 1
# Created sample 72 in 0.0403 seconds
# Creating sample 73 in mode train at location 2867 on chromosome 1
# Created sample 73 in 0.0443 seconds
# Creating sample 74 in mode test at location 2877 on chromosome 1
# Created sample 74 in 0.0415 seconds
# Creating sample 75 in mode train at location 2878 on chromosome 1
# Created sample 75 in 0.0413 seconds
# Creating sample 76 in mode train at location 2918 on chromosome 1
# Created sample 76 in 0.0418 seconds
# Creating sample 77 in mode validation at location 2919 on chromosome 1
# Created sample 77 in 0.0407 seconds
# Creating sample 78 in mode validation at location 2929 on chromosome 1
# Created sample 78 in 0.0409 seconds
# Creating sample 79 in mode train at location 2930 on chromosome 1
# Created sample 79 in 0.0388 seconds
# Creating sample 80 in mode train at location 2977 on chromosome 1
# Created sample 80 in 0.0400 seconds
# Creating sample 81 in mode train at location 2978 on chromosome 1
# Created sample 81 in 0.0421 seconds
# Creating sample 82 in mode validation at location 3019 on chromosome 1
# Created sample 82 in 0.0410 seconds
# Creating sample 83 in mode train at location 3020 on chromosome 1
# Created sample 83 in 0.0398 seconds
# Creating sample 84 in mode train at location 3069 on chromosome 1
# Created sample 84 in 0.0401 seconds
# Creating sample 85 in mode validation at location 3070 on chromosome 1
# Created sample 85 in 0.0431 seconds
# Creating sample 86 in mode train at location 3091 on chromosome 1
# Created sample 86 in 0.0385 seconds
# Creating sample 87 in mode validation at location 3092 on chromosome 1
# Created sample 87 in 0.0416 seconds
# Creating sample 88 in mode train at location 3123 on chromosome 1
# Created sample 88 in 0.0399 seconds
# Creating sample 89 in mode train at location 3124 on chromosome 1
# Created sample 89 in 0.0411 seconds
# Creating sample 90 in mode test at location 3168 on chromosome 1
# Created sample 90 in 0.0393 seconds
# Creating sample 91 in mode train at location 3169 on chromosome 1
# Created sample 91 in 0.0401 seconds
# Creating sample 92 in mode train at location 3292 on chromosome 1
# Created sample 92 in 0.0413 seconds
# Creating sample 93 in mode train at location 3293 on chromosome 1
# Created sample 93 in 0.0425 seconds
# Creating sample 94 in mode train at location 3306 on chromosome 1
# Created sample 94 in 0.0402 seconds
# Creating sample 95 in mode train at location 3307 on chromosome 1
# Created sample 95 in 0.0426 seconds
# Creating sample 96 in mode test at location 3456 on chromosome 1
# Created sample 96 in 0.0438 seconds
# Creating sample 97 in mode train at location 3457 on chromosome 1
# Created sample 97 in 0.0473 seconds
# Creating sample 98 in mode train at location 3518 on chromosome 1
# Created sample 98 in 0.0476 seconds
# Creating sample 99 in mode train at location 3519 on chromosome 1
# Created sample 99 in 0.0426 seconds
# Creating sample 100 in mode train at location 3541 on chromosome 1
# Created sample 100 in 0.0404 seconds
# Creating sample 101 in mode train at location 3542 on chromosome 1
# Created sample 101 in 0.0424 seconds
# Creating sample 102 in mode train at location 3604 on chromosome 1
# Created sample 102 in 0.0410 seconds
# Creating sample 103 in mode train at location 3605 on chromosome 1
# Created sample 103 in 0.0446 seconds
# Creating sample 104 in mode train at location 3673 on chromosome 1
# Created sample 104 in 0.0419 seconds
# Creating sample 105 in mode train at location 3674 on chromosome 1
# Created sample 105 in 0.0426 seconds
# Creating sample 106 in mode train at location 3697 on chromosome 1
# Created sample 106 in 0.0400 seconds
# Creating sample 107 in mode validation at location 3698 on chromosome 1
# Created sample 107 in 0.0435 seconds
# Creating sample 108 in mode train at location 3707 on chromosome 1
# Created sample 108 in 0.0439 seconds
# Creating sample 109 in mode train at location 3708 on chromosome 1
# Created sample 109 in 0.0431 seconds
# Creating sample 110 in mode test at location 3710 on chromosome 1
# Created sample 110 in 0.0454 seconds
# Creating sample 111 in mode train at location 3711 on chromosome 1
# Created sample 111 in 0.0419 seconds
# Creating sample 112 in mode train at location 3713 on chromosome 1
# Created sample 112 in 0.0413 seconds
# Creating sample 113 in mode train at location 3714 on chromosome 1
# Created sample 113 in 0.0392 seconds
# Creating sample 114 in mode train at location 3727 on chromosome 1
# Created sample 114 in 0.0380 seconds
# Creating sample 115 in mode train at location 3728 on chromosome 1
# Created sample 115 in 0.0427 seconds
# Creating sample 116 in mode train at location 3743 on chromosome 1
# Created sample 116 in 0.0396 seconds
# Creating sample 117 in mode train at location 3744 on chromosome 1
# Created sample 117 in 0.0424 seconds
# Creating sample 118 in mode train at location 3747 on chromosome 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/fast/epigenomics/conschti/model.ipynb Cell 10 line 3
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=27'>28</a>         end = end + 1e6
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=30'>31</a> tic = time.perf_counter()
# ---> <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=31'>32</a> create_all_samples()
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=32'>33</a> toc = time.perf_counter()
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=33'>34</a> print(f"Creating all samples in {toc - tic:0.4f} seconds")
#
# /mnt/fast/epigenomics/conschti/model.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a> mode = np.random.choice(["train", "test", "validation"], p=[0.8, 0.1, 0.1])
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=20'>21</a> print(f"Creating sample {i} in mode {mode} at location {site['location']} on chromosome {site['chromosome']}")
# ---> <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=21'>22</a> get_neighbours(site, mode)
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=22'>23</a> toc = time.perf_counter()
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=23'>24</a> print(f"Created sample {i} in {toc - tic:0.4f} seconds")
#
# /mnt/fast/epigenomics/conschti/model.ipynb Cell 10 line 3
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=27'>28</a> # print(f"Histone mods in {toc - tic:0.4f} seconds")
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=28'>29</a> # display(h)
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=29'>30</a> # Get surrounding chromatine states
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=30'>31</a> tic = time.perf_counter()
# ---> <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=31'>32</a> chr_states = client.query_arrow(f"select state, ({site['location']} - start ) as start_diff, ({site['location']} -end) as end_diff from chr_states where chromosome = {site['chromosome']} order by abs(start_diff) limit {cs_neighbours } ")
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=32'>33</a> c = pl.DataFrame(chr_states)
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X12sZmlsZQ%3D%3D?line=34'>35</a> toc = time.perf_counter()
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/clickhouse_connect/driver/client.py:476, in Client.query_arrow(self, query, parameters, settings, use_strings, external_data)
#     474         raise OperationalError(f'Cannot change readonly {arrow_str_setting} to {use_strings}')
#     475     settings[arrow_str_setting] = '1' if use_strings else '0'
# --> 476 return to_arrow(self.raw_query(query,
#     477                                parameters,
#     478                                settings,
#     479                                fmt='Arrow',
#     480                                external_data=external_data))
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/clickhouse_connect/driver/httpclient.py:468, in HttpClient.raw_query(self, query, parameters, settings, fmt, use_database, external_data)
#     466     body = final_query
#     467     fields = None
# --> 468 return self._raw_request(body, params, fields=fields).data
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/clickhouse_connect/driver/httpclient.py:409, in HttpClient._raw_request(self, data, params, headers, method, retries, stream, server_wait, fields, error_handler)
#     407     self._active_session = query_session
#     408 try:
# --> 409     response = self.http.request(method, url, **kwargs)
#     410 except HTTPError as ex:
#     411     if isinstance(ex.__context__, ConnectionResetError):
#     412         # The server closed the connection, probably because the Keep Alive has expired
#     413         # We should be safe to retry, as ClickHouse should not have processed anything on a connection
#     414         # that it killed.  We also only retry this once, as multiple disconnects are unlikely to be
#     415         # related to the Keep Alive settings
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/urllib3/_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/urllib3/_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def get_batch(mode):
    offset = 0. if mode == "train" else 0.9
    sample = 0.9 if mode == "train" else 0.1
    tic = time.perf_counter()
    sites =  client.query_arrow(f"select * except (trinucleotide_context, pedigree, id) from methylome sample {sample} offset {offset} where generation = 0 order by rand() limit {batch_size}")
    toc = time.perf_counter()

    #print(f"fetch batch in {toc - tic:0.4f} seconds")
    df = pl.DataFrame(sites)
    # display(df)

    xs = []
    targets = []
    for site in df.iter_rows(named=True):
        x, target = get_neighbours(site)
        xs.append(x)
        targets.append(target)
   
    data = torch.cat(xs).to(device)
    targets = torch.cat(targets).to(device)
    return data, targets
    
tic = time.perf_counter()
data, targets = get_batch("train")
toc = time.perf_counter()
print(f"Everything in {toc - tic:0.4f} seconds")
print(data, targets)

# %% [markdown]
# # Defining the model

# %%
from torch import nn
from torch.nn import functional as F

class MethylationMaster(nn.Module):
    def __init__(self):
        super().__init__()

        self.transformer = nn.Transformer(d_model=330, nhead=33, dtype=torch.float32)

    def forward(self, x, c, targets = None):
        logits =  self.transformer(c, x, tgt_is_causal=True)
        print(logits.shape) # Should be (gene_length * 6)

        if targets is None:
            return logits, None

        loss = F.mse_loss(logits, targets)

        return logits, loss
    
    @torch.no_grad()
    def generate(self, idx):
        logits = self.transformer(idx, idx) # (B * S, C)

        last = logits[-1]
        last_tar = targets[-1]

        probs = F.softmax(last, dim=-1) 
        # sample from the distribution
        guess = torch.multinomial(probs, num_samples=1) # (B, 1)


        print(f"Guess: {guess}, correct: {last_tar}")

        return guess == last_tar

# %% [markdown]
# # Training

# %%
from torch.utils.data import DataLoader

training_data = Sites(mode="train")
train_dataloader = DataLoader(training_data, batch_size=None)
conschti = MethylationMaster().to(device)

print(sum(p.numel() for p in conschti.parameters())/1e6, 'M parameters')
optimizer = torch.optim.Adam(conschti.parameters(), lr=1e-3)
# Out:
# 24.134376 M parameters
# /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
trainings_steps = 1000

for i in range(trainings_steps):
    optimizer.zero_grad()

    x, c, t = next(iter(train_dataloader))


    logits, loss = conschti(x, c , t)
    loss.backward()
    optimizer.step()
    
    print(f"Step {i}, loss: {loss.item()}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /mnt/fast/epigenomics/conschti/model.ipynb Cell 14 line 6
#       <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> for i in range(trainings_steps):
#       <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     optimizer.zero_grad()
# ----> <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     x, c, t = next(iter(train_dataloader))
#       <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     logits, loss = conschti(x, c , t)
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a>     loss.backward()
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /mnt/fast/epigenomics/conschti/.env/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:41, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      39         raise StopIteration
#      40 else:
# ---> 41     data = next(self.dataset_iter)
#      42 return self.collate_fn(data)
#
# /mnt/fast/epigenomics/conschti/model.ipynb Cell 14 line 4
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=44'>45</a> targets_line_2 = torch.tensor(targets_line_2, dtype=torch.float32)
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=45'>46</a> # targets_line_8 = torch.tensor(targets_line_8, dtype=torch.float32)
# ---> <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=47'>48</a> targets_line_2 = targets_line_2.reshape(gene_length, 6)
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=48'>49</a> # targets_line_8 = targets_line_8.reshape(gene_length, 6)
#      <a href='vscode-notebook-cell:/mnt/fast/epigenomics/conschti/model.ipynb#X16sZmlsZQ%3D%3D?line=50'>51</a> targets_line_2 = targets_line_2[1:, :] # remove first row, these can not be predicted as there is no predecessor
#
# RuntimeError: shape '[2065, 6]' is invalid for input of size 0
